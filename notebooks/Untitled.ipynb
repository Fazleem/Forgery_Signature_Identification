# %%
import numpy as np

# %%
train_data = np.load("../data/interim/train_data.npy", allow_pickle=True)
train_label = np.load("../data/interim/train_labels.npy", allow_pickle=True)
test_data = np.load("../data/interim/test_data.npy", allow_pickle=True)
test_label = np.load("../data/interim/test_labels.npy", allow_pickle=True)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(train_data[400], interpolation='nearest')
plt.show()

# %%
train_label[400]
# Out:
# 1
